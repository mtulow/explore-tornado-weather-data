# %% [markdown]
# # <center> Exporatory Data Analysis </center>
# ---

# %% [markdown]
# ## Objective
# ---

# %% [markdown]
# ...

# %% [markdown]
# ## Strategy
# ---

# %% [markdown]
# ...

# %% [markdown]
# ## Step 0: Import required packages
# ---

# %% [markdown]
# packages:
# - [datetime]()
# - [io]()
# - [cartopy]()
# - [matplotlib]()
# - [metpy]()
# - [siphon]()

# %%
# !pip install -q folium cartopy metpy siphon "xarray[complete]"

# %%
import folium
import datetime as dt

import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Notice that we will use "plt" to access matplotlib
import matplotlib.pyplot as plt

import metpy.calc as mpcalc
import metpy.plots as mpplots

import numpy as np
import pandas as pd
import geopandas as gpd

from matplotlib.patheffects import withStroke
from metpy.io import parse_metar_file
from metpy.units import pandas_dataframe_to_unit_arrays

# Here is where we import the TDSCatalog class from siphon for obtaining our data 
from siphon.catalog import TDSCatalog

# %% [markdown]
# ## ...
# ---

# %% [markdown]
# https://thredds.ucar.edu/

# %%
# Tornado Data Files
tornado_path_files = '../data/tornadoes/paths_1950-2022.shp'
tornado_starting_point_files = '../data/tornadoes/starting_points_1950-2022.shp'

# %%
paths = gpd.read_file(tornado_path_files)
paths
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 0         192  1950  10   1  1950-10-01  21:00:00   3  OK   40   23  ...
# 1         193  1950  10   9  1950-10-09  02:15:00   3  NC   37    9  ...
# 2         195  1950  11  20  1950-11-20  02:20:00   3  KY   21    1  ...
# 3         196  1950  11  20  1950-11-20  04:00:00   3  KY   21    2  ...
# 4         197  1950  11  20  1950-11-20  07:30:00   3  MS   28   14  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 68696  621922  2022   9  28  2022-09-28  13:32:00   3  FL   12    0  ...
# 68697  621923  2022   9  30  2022-09-30  10:25:00   3  NC   37    0  ...
# 68698  621924  2022   9  30  2022-09-30  13:22:00   3  NC   37    0  ...
# 68699  621900  2022   9   4  2022-09-04  15:44:00   3  OH   39    0  ...
# 68700  621901  2022   9   9  2022-09-09  23:21:00   3  SC   45    0  ...
#
#           loss  closs     slat      slon     elat      elon    len  wid  fc  \
# ...

# %%
# starting_points = gpd.read_file(tornado_starting_point_files)
# starting_points

# %% [markdown]
# ---

# %%
central_lat = 37.5
central_lon = -96
extent = [-120, -70, 24, 50.5]
central_lon = np.mean(extent[:2])
central_lat = np.mean(extent[2:])

plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent(extent)

ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.LAKES, edgecolor='black')
ax.add_feature(cfeature.RIVERS)
ax.gridlines()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
